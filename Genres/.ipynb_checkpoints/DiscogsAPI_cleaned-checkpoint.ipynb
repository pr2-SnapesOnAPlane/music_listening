# %%
#import dependencies
import pandas as pd
import requests
import discogs_client
import time

# %%
#instantiate the discogs client object and save to a variable
d = discogs_client.Client('BranDunn', consumer_key=None, consumer_secret=None, token=None, secret=None, user_token=api_key)

# %%
#read in csv from scraper
df = pd.read_csv('riaa_scrape_records.csv')
df.head()
# Out:
#    Unnamed: 0           Artist                                   Title  \
# 0           0           EAGLES  EAGLES/THEIR GREATEST HITS 1971 - 1975
# 1           1  MICHAEL JACKSON                                THRILLER
# 2           2           EAGLES                        HOTEL CALIFORNIA
# 3           3       BILLY JOEL      GREATEST HITS VOLUME I & VOLUME II
# 4           4     LED ZEPPELIN                         LED ZEPPELIN IV
#
#           Label Format  Certified Units (Millions)
# 0         RHINO  ALBUM                        38.0
# 1  EPIC RECORDS  ALBUM                        33.0
# 2         RHINO  ALBUM                        26.0
# 3      COLUMBIA  ALBUM                        23.0
# 4      ATLANTIC  ALBUM                        23.0

# %%
#create a smaller df for testing 
#df = df.head()

# %%
#test query to return a single item by searching for the first album in the scraped dataframe
results = d.search('EAGLES/THEIR GREATEST HITS 1971 - 1975', type='release')
print(results)

# %%
#select the first result from the list
album = results[0]
album
# Out:
# <Release 2665875 'Eagles - Their Greatest Hits 1971-1975'>

# %%
#get the desired attribute of the selected response
album.genres
# Out:
# ['Rock']

# %%
#create empty list to hold respose data
genre_list = []

#perform multiple searches of the API database for genres based on artists, by iterrating through the artist column in scrapped df
for i, row in df.iterrows():
    if i > 200:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
#discogs requires that the requests not occur too quickly, but that the total elapsed time of the request also not 
#exceed a certain amount. Breaking the request into multiple parts, 200 requests each.
for i, row in df.iterrows():
    if i < 201:
        continue
    elif i > 400:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 401:
        continue
    elif i > 600:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 601:
        continue
    elif i > 800:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 801:
        continue
    elif i > 1000:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 1001:
        continue
    elif i > 1200:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 1201:
        continue
    elif i > 1400:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 1401:
        continue
    elif i > 1600:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 1601:
        continue
    elif i > 1800:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 1801:
        continue
    elif i > 2000:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 2001:
        continue
    elif i > 2200:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
for i, row in df.iterrows():
    if i < 2201:
        continue
    elif i > 2336:
        break
    results = d.search(row['Artist'], type='release')
    time.sleep(2)
    try:
        genres = (results[0].genres, i)
        #print(genres)
        genre_list.append(genres)
    except:
        unknown = ('unknown', i)
        genre_list.append(unknown)

# %%
genre_list
# Out:
# [(['Rock'], 0),
#  (['Electronic', 'Rock', 'Funk / Soul', 'Pop'], 1),
#  (['Rock'], 2),
#  (['Rock', 'Pop'], 3),
#  (['Rock'], 4),
#  (['Rock'], 5),
#  (['Electronic'], 6),
#  (['Folk, World, & Country'], 7),
#  (['Rock'], 8),
#  (['Rock'], 9),
#  (['Rock', 'Folk, World, & Country'], 10),
#  (['Rock'], 11),
#  (['Rock'], 12),
#  (['Electronic', 'Funk / Soul'], 13),
#  (['Rock'], 14),
#  (['Rock'], 15),
#  (['Folk, World, & Country'], 16),
#  (['Rock'], 17),
#  (['Rock', 'Pop'], 18),
#  (['Rock'], 19),
#  (['Rock'], 20),
#  (['Rock'], 21),
#  (['Reggae'], 22),
#  (['Rock'], 23),
#  (['Rock'], 24),
#  (['Rock'], 25),
#  (['Rock', 'Latin', 'Funk / Soul'], 26),
#  (['Rock'], 27),
#  (['Funk / Soul', 'Pop'], 28),
#  (['Rock'], 29),
#  (['Electronic', 'Hip Hop', 'Pop'], 30),
#  (['Folk, World, & Country'], 31),
#  (['Rock', 'Pop'], 32),
#  (['Rock'], 33),
#  (['Rock', 'Pop'], 34),
#  (['Rock'], 35),
#  (['Rock'], 36),
#  (['Rock'], 37),
#  (['Electronic'], 38),
# ...

# %%
#convert genre_list to a dataframe
genre_df = pd.DataFrame(genre_list, columns=['Genre', 'Index'])
genre_df.head(10)
# Out:
#                                   Genre  Index
# 0                                [Rock]      0
# 1  [Electronic, Rock, Funk / Soul, Pop]      1
# 2                                [Rock]      2
# 3                           [Rock, Pop]      3
# 4                                [Rock]      4
# 5                                [Rock]      5
# 6                          [Electronic]      6
# 7              [Folk, World, & Country]      7
# 8                                [Rock]      8
# 9                                [Rock]      9

# %%
#store results as a csv with 2 columns: 'genre' and 'index'
genre_df.to_csv('clean_genres.csv')
