# %%
# Ignore SQLITE warnings related to Decimal numbers in the music database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
import pymysql
import pandas as pd
import json

# %%
# Create an engine for the music.sql database
#engine = create_engine("sqlite:///../Resources/music.sql", echo=False)
engine = create_engine('mysql+pymysql://root:Unicorn1!@localhost/music')

# %%
# Save a reference to the music table as `Music`
music_df = pd.read_sql("SELECT * FROM music", engine)
music_df.head()
# Out:
#   main_genre   sub_genre           artist              title  cert_units_mm
# 0      Blues       Blues      NORAH JONES  COME AWAY WITH ME             10
# 1      Blues       Blues      TINA TURNER     PRIVATE DANCER              5
# 2      Blues       Blues      NORAH JONES    FEELS LIKE HOME              4
# 3      Blues       Blues  PLAIN WHITE T'S  HEY THERE DELILAH              4
# 4      Blues  Blues, Pop            BAZZI               MINE              2

# %%
music_df.main_genre.unique()
# Out:
# array(['Blues', 'Classical', 'Electronic', 'Country', 'Funk', 'Hip Hop',
#        'Jazz', 'Latin', 'Non-Music', 'Pop', 'Reggae', 'Rock',
#        'Stage & Screen'], dtype=object)

# %%
starting_point = {'name':'flare', 'children':[]}
# iterate through each unique genre
for genre in music_df.main_genre.unique():
# with genre append to flare children
    genre_dict ={'name':genre, 'children':[]}
    
    subset_artist = music_df[music_df.main_genre==genre]
    for artist in subset_artist.artist.unique():
        artist_dict = {'name':artist, 'children':[]}
        
        
        subset_album = subset_artist[subset_artist.artist == artist]
        for i, row in subset_album.iterrows():
            album_dict={'name': row['title'], 'size':row['cert_units_mm']}
            artist_dict['children'].append(album_dict)
        #append to genre dictionary after iterating through albums
        genre_dict['children'].append(artist_dict)
    starting_point['children'].append(genre_dict)

# # iterate through each artist in specified genre

# append to genre_dict children


# iterate through each song with artist (in specific genre)

# append t0 artist children

# %%
#for i, row in music_df.iterrows():
#    print(i)
#    print(row['title'])
# Out:
# 0
# COME AWAY WITH ME
# 1
# PRIVATE DANCER
# 2
# FEELS LIKE HOME
# 3
# HEY THERE DELILAH
# 4
# MINE
# 5
# EX'S & OH'S
# 6
# IN CONCERT
# 7
# CHANT
# 8
# BACK IN BLACK
# 9
# PURPLE RAIN (SOUNDTRACK)
# 10
# BABY (FEAT. LUDACRIS)
# 11
# PARTY ROCK ANTHEM
# 12
# GREAT BAND ERA
# 13
# SORRY
# 14
# THROWING COPPER
# 15
# SEXY AND I KNOW IT
# 16
# HANGIN' TOUGH
# 17
# HIGHWAY TO HELL
# 18
# LOVE YOURSELF
# 19
# DIRTY DEEDS DONE DIRT CHEAP
# 20
# POMPEII
# 21
# THE SCORE
# 22
# DOWN
# 23
# BOYFRIEND
# 24
# WHAT DO YOU MEAN
# 25
# A FRESH AIRE CHRISTMAS
# 26
# MANNHEIM STEAMROLLER CHRISTMAS
# 27
# GIVE ME EVERYTHING (FEAT. NE-YO, AFROJACK, & NAYER)
# 28
# HOTSHOT
# 29
# NOW THAT'S WHAT I CALL CHRISTMAS!
# 30
# THE RAZORS EDGE
# 31
# WHO MADE WHO
# 32
# A CHRISTMAS ALBUM
# 33
# GREATEST HITS VOLUME II
# 34
# GUILTY
# 35
# MEMORIES
# 36
# ...AND THEN THERE WAS X
# 37
# THE DUTCHESS
# 38
# MASK OFF
# 39
# LOW LIFE (FEAT. THE WEEKND)
# 40
# NEVER SAY NEVER
# 41
# ONE TIME
# 42
# LOCATION
# 43
# ...

# %%
#subset_artist[subset_artist.artist == artist]

# %%
starting_point
# Out:
# {'name': 'flare',
#  'children': [{'name': 'Blues',
#    'children': [{'name': 'NORAH JONES',
#      'children': [{'name': 'COME AWAY WITH ME', 'size': 10},
#       {'name': 'FEELS LIKE HOME', 'size': 4}]},
#     {'name': 'TINA TURNER',
#      'children': [{'name': 'PRIVATE DANCER', 'size': 5}]},
#     {'name': "PLAIN WHITE T'S",
#      'children': [{'name': 'HEY THERE DELILAH', 'size': 4}]},
#     {'name': 'BAZZI', 'children': [{'name': 'MINE', 'size': 2}]},
#     {'name': 'ELLE KING', 'children': [{'name': "EX'S & OH'S", 'size': 2}]}]},
#   {'name': 'Classical',
#    'children': [{'name': 'THE THREE TENORS',
#      'children': [{'name': 'IN CONCERT', 'size': 3}]},
#     {'name': 'BENEDICTINE MONKS-SANTO DE SIL',
#      'children': [{'name': 'CHANT', 'size': 2}]}]},
#   {'name': 'Electronic',
#    'children': [{'name': 'AC/DC',
#      'children': [{'name': 'BACK IN BLACK', 'size': 22},
#       {'name': 'HIGHWAY TO HELL', 'size': 7},
# ...

# %%
json.dumps(starting_point)
# Out:
# '{"name": "flare", "children": [{"name": "Blues", "children": [{"name": "NORAH JONES", "children": [{"name": "COME AWAY WITH ME", "size": 10}, {"name": "FEELS LIKE HOME", "size": 4}]}, {"name": "TINA TURNER", "children": [{"name": "PRIVATE DANCER", "size": 5}]}, {"name": "PLAIN WHITE T\'S", "children": [{"name": "HEY THERE DELILAH", "size": 4}]}, {"name": "BAZZI", "children": [{"name": "MINE", "size": 2}]}, {"name": "ELLE KING", "children": [{"name": "EX\'S & OH\'S", "size": 2}]}]}, {"name": "Classical", "children": [{"name": "THE THREE TENORS", "children": [{"name": "IN CONCERT", "size": 3}]}, {"name": "BENEDICTINE MONKS-SANTO DE SIL", "children": [{"name": "CHANT", "size": 2}]}]}, {"name": "Electronic", "children": [{"name": "AC/DC", "children": [{"name": "BACK IN BLACK", "size": 22}, {"name": "HIGHWAY TO HELL", "size": 7}, {"name": "DIRTY DEEDS DONE DIRT CHEAP", "size": 6}, {"name": "THE RAZORS EDGE", "size": 5}, {"name": "WHO MADE WHO", "size": 5}, {"name": "FOR THOSE ABOUT TO RO
# ...

# %%
with open('nested_dict.json', 'w') as f:
    json.dump(starting_point, f)
